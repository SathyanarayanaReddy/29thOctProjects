# %%
#Import pandas
import pandas as pd
 
# read by default 1st sheet of an excel file
dataframe1 = pd.read_excel('C:\Top\delivery_time.xlsx')
 
print(dataframe1)
# Out:
#     Delivery Time  Sorting Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
#Import seaborn
import seaborn as sb
import matplotlib.pyplot as plt
data1 = dataframe1
print(data1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Delivery Time  21 non-null     float64
#  1   Sorting Time   21 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 468.0 bytes
# None

# %%
#copy Data
data2 = data1.copy()
print(data2)
# Out:
#     Delivery Time  Sorting Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
sb.regplot(x = 'Delivery Time' , y = 'Sorting Time' , data = data2)
# Out:
# <Axes: xlabel='Delivery Time', ylabel='Sorting Time'>

# %%
sb.lineplot(x = 'Delivery Time' , y = 'Sorting Time' , data = data2)
# Out:
# <Axes: xlabel='Delivery Time', ylabel='Sorting Time'>

# %%
#increase Delivery time
sb.displot(x = data2['Delivery Time'])

# %%
sb.boxplot(x = data2['Delivery Time'])
# Out:
# <Axes: xlabel='Delivery Time'>

# %%
X = data1['Delivery Time'].values
X = X.reshape(-1,1)
print(X)
# Out:
# [[21.  ]
#  [13.5 ]
#  [19.75]
#  [24.  ]
#  [29.  ]
#  [15.35]
#  [19.  ]
#  [ 9.5 ]
#  [17.9 ]
#  [18.75]
#  [19.83]
#  [10.75]
#  [16.68]
#  [11.5 ]
#  [12.03]
#  [14.88]
#  [13.75]
#  [18.11]
#  [ 8.  ]
#  [17.83]
#  [21.5 ]]

# %%
Y = data1['Sorting Time'].values
Y = Y.reshape(-1,1)
print(Y)
# Out:
# [[10]
#  [ 4]
#  [ 6]
#  [ 9]
#  [10]
#  [ 6]
#  [ 7]
#  [ 3]
#  [10]
#  [ 9]
#  [ 8]
#  [ 4]
#  [ 7]
#  [ 3]
#  [ 3]
#  [ 4]
#  [ 6]
#  [ 7]
#  [ 2]
#  [ 7]
#  [ 5]]

# %%
#Import sklearn
from sklearn.linear_model import LinearRegression
#Create LinearRegression model
model = LinearRegression()
print(model)
# Out:
# LinearRegression()

# %%
#fit the model
model_fit = model.fit(X,Y)
print(model_fit)
# Out:
# LinearRegression()

# %%
#coeffiecent 
model_fit.coef_
# Out:
# array([[0.41374363]])

# %%
model_fit.intercept_
# Out:
# array([-0.75667337])

# %%
sortingtime = 11
DeliveryTime = 0.41374363 * sortingtime + -0.75667337
print(DeliveryTime)
# Out:
# 3.79450656

# %%
#DeliveryTime predicted values
predict = model_fit.predict(X)
predict
# Out:
# array([[ 7.93194282],
#        [ 4.82886561],
#        [ 7.41476329],
#        [ 9.17317371],
#        [11.24189185],
#        [ 5.59429132],
#        [ 7.10445557],
#        [ 3.1738911 ],
#        [ 6.64933758],
#        [ 7.00101966],
#        [ 7.44786278],
#        [ 3.69107064],
#        [ 6.14457035],
#        [ 4.00137836],
#        [ 4.22066248],
#        [ 5.39983182],
#        [ 4.93230152],
#        [ 6.73622374],
#        [ 2.55327566],
#        [ 6.62037552],
#        [ 8.13881464]])

# %%
datamodel = data2
datamodel
# Out:
#     Delivery Time  Sorting Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
datamodel.corr()
# Out:
#                Delivery Time  Sorting Time
# Delivery Time       1.000000      0.825997
# Sorting Time        0.825997      1.000000

# %%
#sampling data test and training data
from sklearn.model_selection import train_test_split
datamodel.shape
# Out:
# (21, 2)

# %%
#splitting data training data 80%,testing data 20%
training,testing = train_test_split(datamodel,train_size=0.8)

# %%
training.shape
# Out:
# (16, 2)

# %%
testing.shape
# Out:
# (5, 2)

# %%
datamodel.shape
# Out:
# (21, 2)

# %%
datamodel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Delivery Time  21 non-null     float64
#  1   Sorting Time   21 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 468.0 bytes

# %%
x = datamodel['Delivery Time']
y = datamodel['Sorting Time']
X_train,X_test,y_train,y_test = train_test_split(x,y,train_size=0.8)

# %%
X_train=X_train.values.reshape(-1,1)

# %%
y_train=y_train.values.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression

# %%
linreg_mean_dif = LinearRegression().fit(X_train, y_train)

# %%
linreg_mean_dif.coef_
# Out:
# array([[0.40513733]])

# %%
linreg_mean_dif.intercept_
# Out:
# array([-0.88556205])

# %%
X_test = X_test.values.reshape(-1,1)

# %%
pred = linreg_mean_dif.predict(X_test)
pred
# Out:
# array([[3.46966419],
#        [7.62232178],
#        [4.68507617],
#        [7.14831111],
#        [5.33329589]])

# %%
df_pred = pd.DataFrame(pred,columns = ['predicted'] )

# %%
df_pred['Actual'] = y_test.values
df_pred
# Out:
#    predicted  Actual
# 0   3.469664       4
# 1   7.622322      10
# 2   4.685076       6
# 3   7.148311       8
# 4   5.333296       6

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from math import sqrt

# %%
r2_score(df_pred['Actual'],df_pred['predicted'])
# Out:
# 0.5753123641246359

# %%
sqrt(mean_squared_error(df_pred['Actual'],df_pred['predicted']))
# Out:
# 1.329172887641602
